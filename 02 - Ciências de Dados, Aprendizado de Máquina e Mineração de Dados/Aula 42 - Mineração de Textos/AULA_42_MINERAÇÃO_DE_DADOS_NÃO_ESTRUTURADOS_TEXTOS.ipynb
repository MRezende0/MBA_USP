# %% [markdown]
# # <font color="red"> MBA em IA e Big Data</font>
# ## <span style="color:red">Curso 2 - Ciência de Dados, Aprendizado de Máquina e Mineração de Dados</span>
#
# ### <span style="color:darkred">Mineração de Dados</span>
#
# #### Material de Apoio - Experimentos com Dados não Estruturados - Textos (ver Vídeo)
#
# *Ricardo M. Marcacini*<br>
# *ICMC/USP São Carlos*

# %% [markdown]
# # Importando bibliotecas

# %%
import pandas as pd
# !pip install -U sentence-transformers
from sentence_transformers import SentenceTransformer, util
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
# Out:
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.1.1-py3-none-any.whl.metadata (16 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-4.57.0-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (2.8.0)
# Requirement already satisfied: scikit-learn in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: scipy in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (1.14.0)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Downloading huggingface_hub-0.35.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: Pillow in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (4.12.2)
# Requirement already satisfied: filelock in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading regex-2025.9.18-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading safetensors-0.6.2-cp38-abi3-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.7.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.8.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\matheus.rezende\appdata\roaming\python\python312\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.1.31)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\matheus.rezende\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Downloading sentence_transformers-5.1.1-py3-none-any.whl (486 kB)
# Downloading transformers-4.57.0-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.0 MB 9.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/12.0 MB 4.4 MB/s eta 0:00:03
#    ------- -------------------------------- 2.4/12.0 MB 3.8 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/12.0 MB 4.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.0/12.0 MB 4.8 MB/s eta 0:00:02
#    ------------------- -------------------- 5.8/12.0 MB 4.8 MB/s eta 0:00:02
#    --------------------- ------------------ 6.6/12.0 MB 4.7 MB/s eta 0:00:02
#    --------------------- ------------------ 6.6/12.0 MB 4.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.1/12.0 MB 4.0 MB/s eta 0:00:02
#    -------------------------- ------------- 7.9/12.0 MB 3.8 MB/s eta 0:00:02
#    --------------------------- ------------ 8.1/12.0 MB 3.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.9/12.0 MB 3.5 MB/s eta 0:00:01
#    -------------------------------- ------- 9.7/12.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.5/12.0 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------ --- 11.0/12.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.0 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.0 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.0 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.0 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.0 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 2.7 MB/s  0:00:04
# Downloading huggingface_hub-0.35.3-py3-none-any.whl (564 kB)
#    ---------------------------------------- 0.0/564.3 kB ? eta -:--:--
#    ------------------------------------- -- 524.3/564.3 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 564.3/564.3 kB 1.2 MB/s  0:00:00
# Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 4.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.6/2.7 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.7 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.7 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 2.8 MB/s  0:00:00
# Downloading regex-2025.9.18-cp312-cp312-win_amd64.whl (275 kB)
# Downloading safetensors-0.6.2-cp38-abi3-win_amd64.whl (320 kB)
# Installing collected packages: safetensors, regex, huggingface-hub, tokenizers, transformers, sentence-transformers
#
#    ---------------------------------------- 0/6 [safetensors]
#    ---------------------------------------- 0/6 [safetensors]
#    ---------------------------------------- 0/6 [safetensors]
#    ---------------------------------------- 0/6 [safetensors]
#    ------ --------------------------------- 1/6 [regex]
#    ------ --------------------------------- 1/6 [regex]
#    ------ --------------------------------- 1/6 [regex]
#    ------ --------------------------------- 1/6 [regex]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [tokenizers]
#    -------------------- ------------------- 3/6 [tokenizers]
#    -------------------- ------------------- 3/6 [tokenizers]
#    -------------------- ------------------- 3/6 [tokenizers]
#    -------------------- ------------------- 3/6 [tokenizers]
#    -------------------- ------------------- 3/6 [tokenizers]
#    -------------------- ------------------- 3/6 [tokenizers]
#    -------------------- ------------------- 3/6 [tokenizers]
#    -------------------- ------------------- 3/6 [tokenizers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
# ...
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    ---------------------------------------- 6/6 [sentence-transformers]
#
# Successfully installed huggingface-hub-0.35.3 regex-2025.9.18 safetensors-0.6.2 sentence-transformers-5.1.1 tokenizers-0.22.1 transformers-4.57.0
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: Uma rotina de inicialização da biblioteca de vínculo dinâmico (DLL) falhou.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 get_ipython().system('pip install -U sentence-transformers')
# ----> 3 from sentence_transformers import SentenceTransformer, util
#       4 from sklearn.model_selection import train_test_split
#       5 from sklearn.neighbors import KNeighborsClassifier
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\sentence_transformers\cross_encoder\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:16
#      14 from torch import nn
#      15 from tqdm.autonotebook import trange
# ---> 16 from transformers import (
#      17     AutoConfig,
#      18     AutoModelForSequenceClassification,
#      19     AutoTokenizer,
#      20     PretrainedConfig,
#      21     PreTrainedModel,
#      22     PreTrainedTokenizer,
#      23 )
#      24 from transformers.utils import PushToHubMixin
#      25 from typing_extensions import deprecated
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2315 elif name in self._class_to_module:
#    2316     try:
# -> 2317         module = self._get_module(self._class_to_module[name])
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2343 def _get_module(self, module_name: str):
#    2344     try:
# -> 2345         return importlib.import_module("." + module_name, self.__name__)
#    2346     except Exception as e:
#    2347         raise e
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\modeling_utils.py:70
#      60 from .integrations.sdpa_paged import sdpa_attention_paged_forward
#      61 from .integrations.tensor_parallel import (
#      62     _get_parameter_tp_plan,
#      63     distribute_model,
#    (...)
#      68     verify_tp_plan,
#      69 )
# ---> 70 from .loss.loss_utils import LOSS_MAPPING
#      71 from .modeling_flash_attention_utils import lazy_import_flash_attention
#      72 from .pytorch_utils import id_tensor_storage
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\loss\loss_utils.py:21
#      18 import torch.nn as nn
#      19 from torch.nn import BCEWithLogitsLoss, MSELoss
# ---> 21 from .loss_d_fine import DFineForObjectDetectionLoss
#      22 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#      23 from .loss_for_object_detection import ForObjectDetectionLoss, ForSegmentationLoss
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\loss\loss_d_fine.py:21
#      18 import torch.nn.functional as F
#      20 from ..utils import is_vision_available
# ---> 21 from .loss_for_object_detection import (
#      22     box_iou,
#      23 )
#      24 from .loss_rt_detr import RTDetrHungarianMatcher, RTDetrLoss
#      27 if is_vision_available():
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\loss\loss_for_object_detection.py:32
#      28     from scipy.optimize import linear_sum_assignment
#      31 if is_vision_available():
# ---> 32     from transformers.image_transforms import center_to_corners_format
#      35 def dice_loss(inputs, targets, num_boxes):
#      36     """
#      37     Compute the DICE loss, similar to generalized IOU for masks
#      38
#    (...)
#      44                  class).
#      45     """
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\image_transforms.py:48
#      45     import torch
#      47 if is_tf_available():
# ---> 48     import tensorflow as tf
#      50 if is_flax_available():
#      51     import jax.numpy as jnp
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# File c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:88
#      86     sys.setdlopenflags(_default_dlopen_flags)
#      87 except ImportError:
# ---> 88   raise ImportError(
#      89       f'{traceback.format_exc()}'
#      90       f'\n\nFailed to load the native TensorFlow runtime.\n'
#      91       f'See https://www.tensorflow.org/install/errors '
#      92       f'for some common causes and solutions.\n'
#      93       f'If you need help, create an issue '
#      94       f'at https://github.com/tensorflow/tensorflow/issues '
#      95       f'and include the entire stack trace above this error message.')
#      97 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "c:\Users\matheus.rezende\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 73, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: Uma rotina de inicialização da biblioteca de vínculo dinâmico (DLL) falhou.
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.

# %% [markdown]
# # Carregando base de dados
#
#
# Dmoz-Sports-500 are composed by web pages of the sports category extracted from DMOZ - Open Directory Project. The document class are the subcateries of the sports category. We consider 500 document for each class.
#
#
# Rossi, Rafael Geraldeli, Ricardo Marcondes Marcacini, and Solange Oliveira Rezende. "Benchmarking text collections for classification and clustering tasks.". University of São Paulo. Technical Report. (2013).
# http://repositorio.icmc.usp.br//handle/RIICMC/6641

# %%
df = pd.read_csv('Dmoz-Sports.csv')
df
# Out:
#          file_name                                               text  \
# 0      3191005.txt  Bryant Bulldogs Official site with news, sched...
# 1      3193010.txt  Hirschbeck v. Alomar Covers a legal case betwe...
# 2      3190744.txt  Mountaineers Baseball Official site. Includes ...
# 3      3193695.txt  M.S.H. Little League Contains news items, a li...
# 4      3193486.txt  Quotations: Bob Uecker Baseball Almanac collec...
# ...            ...                                                ...
# 13495  3274147.txt  IMDb.com - Dwayne Johnson Filmography, awards,...
# 13496  3273536.txt  Suwannee Wrestling Includes pictures, and stat...
# 13497  3274032.txt   Jeff's Swanton Biography, facts and wallpapers.
# 13498  3274152.txt  Roddy Piper Tribute Includes background inform...
# 13499  3273727.txt  The Wrestler Revue Online magazine featuring i...
#
#            class
# 0       Baseball
# 1       Baseball
# 2       Baseball
# 3       Baseball
# 4       Baseball
# ...          ...
# 13495  Wrestling
# 13496  Wrestling
# 13497  Wrestling
# 13498  Wrestling
# 13499  Wrestling
#
# [13500 rows x 3 columns]

# %%
print(df['class'].unique())
print(len(df['class'].unique()))
# Out:
# ['Baseball' 'Basketball' 'Bowling' 'Cricket' 'Cycling' 'Equestrian'
#  'Fencing' 'Flying' 'Football' 'Golf' 'Gymnastics' 'Hockey' 'Lacrosse'
#  'Martial' 'Motorsports' 'Paintball' 'Running' 'Skating' 'Soccer'
#  'Softball' 'Strength' 'Tennis' 'Track' 'Volleyball' 'Water' 'Winter'
#  'Wrestling']
# 27

# %% [markdown]
# # Pré-processamento dos Textos
#
# Vamos usar um modelo pré-treinado para extrair características dos textos.
#
# Veja os modelos pré-treinados disponíveis na biblioteca proposta (sentence-transformers): https://www.sbert.net/docs/pretrained_models.html

# %%
text_feature_extractor = SentenceTransformer('paraphrase-multilingual-mpnet-base-v2')

# %% [markdown]
# ### Testando a representação

# %%
texto1 = "A menina chutou a bola no gol"
texto2 = "Crianças gostam de praticar esportes"
texto3 = "A inflação está aumentando"
texto4 = "The girl plays football"

dataset = [texto1, texto2, texto3, texto4]
dataset
# Out:
# ['A menina chutou a bola no gol',
#  'Crianças gostam de praticar esportes',
#  'A inflação está aumentando',
#  'The girl plays football']

# %%
X = text_feature_extractor.encode(dataset)
X
# Out:
# array([[-0.04990399, -0.10120969, -0.01776708, ...,  0.08765166,
#          0.10532034, -0.02653974],
#        [-0.1827991 , -0.14581765, -0.01475725, ...,  0.22304882,
#          0.2835558 , -0.0597906 ],
#        [-0.10946287, -0.02651667, -0.01413278, ..., -0.05574905,
#         -0.13470888, -0.00053339],
#        [-0.1311327 ,  0.05632214, -0.0117345 , ...,  0.18818966,
#          0.12022091, -0.06361013]], dtype=float32)

# %%
pd.DataFrame(X)
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.049904 -0.101210 -0.017767  0.040031  0.163654 -0.112286 -0.152568
# 1 -0.182799 -0.145818 -0.014757  0.171981  0.053201 -0.072936 -0.022060
# 2 -0.109463 -0.026517 -0.014133  0.099378  0.007704  0.154726 -0.134314
# 3 -0.131133  0.056322 -0.011734 -0.025238  0.137596 -0.031775 -0.206477
#
#         7         8         9    ...       758       759       760       761  \
# 0  0.158626 -0.150821  0.055745  ...  0.025651  0.164021 -0.198006 -0.093803
# 1  0.049558  0.082029 -0.107070  ...  0.001167  0.028555 -0.169803 -0.126898
# 2  0.031381 -0.006636  0.214759  ...  0.007699  0.041511 -0.039930 -0.067037
# 3  0.239817 -0.081239 -0.039377  ...  0.003737  0.187751 -0.059036 -0.078171
#
#         762       763       764       765       766       767
# 0  0.001125  0.245816  0.088471  0.087652  0.105320 -0.026540
# 1 -0.101996  0.204959  0.046652  0.223049  0.283556 -0.059791
# 2  0.101316 -0.232816  0.092790 -0.055749 -0.134709 -0.000533
# 3 -0.072765  0.329974  0.070836  0.188190  0.120221 -0.063610
#
# [4 rows x 768 columns]

# %%
for i in range(0, len(X)-1):
  for j in range(i+1,len(X)):
    print('Similaridade entre A e B')
    print('A = ',dataset[i])
    print('B = ',dataset[j])
    print(util.cos_sim(X[i], X[j]).numpy()[0][0])
    print('-------')
# Out:
# Similaridade entre A e B
# A =  A menina chutou a bola no gol
# B =  Crianças gostam de praticar esportes
# 0.45085272
# -------
# Similaridade entre A e B
# A =  A menina chutou a bola no gol
# B =  A inflação está aumentando
# 0.068717934
# -------
# Similaridade entre A e B
# A =  A menina chutou a bola no gol
# B =  The girl plays football
# 0.63144743
# -------
# Similaridade entre A e B
# A =  Crianças gostam de praticar esportes
# B =  A inflação está aumentando
# 0.08299054
# -------
# Similaridade entre A e B
# A =  Crianças gostam de praticar esportes
# B =  The girl plays football
# 0.43461877
# -------
# Similaridade entre A e B
# A =  A inflação está aumentando
# B =  The girl plays football
# 0.046365224
# -------

# %% [markdown]
# ## Pré-processando a base de textos

# %%
X = text_feature_extractor.encode(df.text.to_list())

# %%
df['text_features'] = list(X)
df
# Out:
#          file_name                                               text  \
# 0      3191005.txt  Bryant Bulldogs Official site with news, sched...
# 1      3193010.txt  Hirschbeck v. Alomar Covers a legal case betwe...
# 2      3190744.txt  Mountaineers Baseball Official site. Includes ...
# 3      3193695.txt  M.S.H. Little League Contains news items, a li...
# 4      3193486.txt  Quotations: Bob Uecker Baseball Almanac collec...
# ...            ...                                                ...
# 13495  3274147.txt  IMDb.com - Dwayne Johnson Filmography, awards,...
# 13496  3273536.txt  Suwannee Wrestling Includes pictures, and stat...
# 13497  3274032.txt   Jeff's Swanton Biography, facts and wallpapers.
# 13498  3274152.txt  Roddy Piper Tribute Includes background inform...
# 13499  3273727.txt  The Wrestler Revue Online magazine featuring i...
#
#            class                                      text_features
# 0       Baseball  [-0.036046587, 0.13251913, -0.0038513546, 0.05...
# 1       Baseball  [0.003961856, -0.19437294, -0.008163866, 0.146...
# 2       Baseball  [-0.1350075, 0.12867971, 0.0032569494, 0.19287...
# 3       Baseball  [-0.18122779, -0.03957395, -0.004045443, 0.156...
# 4       Baseball  [-0.036253452, -0.009609588, -0.001147742, 0.0...
# ...          ...                                                ...
# 13495  Wrestling  [-0.056194462, 0.3082657, -0.0043185647, 0.046...
# 13496  Wrestling  [-0.07753967, 0.25586662, -0.002476903, 0.0779...
# 13497  Wrestling  [-0.010930059, 0.26063913, -0.006104652, 0.083...
# 13498  Wrestling  [-0.14966059, 0.21381713, -0.0061597005, 0.144...
# 13499  Wrestling  [0.07162647, 0.4078627, -0.0018751748, 0.08798...
#
# [13500 rows x 4 columns]

# %% [markdown]
# # Experimentando um classificador k-NN
#
# Para o nosso teste (simples), vamos dividir o conjunto de dados em 80% para treinamento e 20% para teste.

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)

# %%
df_train
# Out:
#                 file_name                                               text  \
# 12745  Sports_3272758.txt  Perfect North Slopes Located just west of Cinc...
# 2450          3203677.txt  Flatland Place Old school tricks and flatland ...
# 8261          3247702.txt  Lawrence University Cross Country Vikings. Coa...
# 7058          3243555.txt  Fairmont Raceway This 1/2 mile, high banked, d...
# 6141          3235572.txt  Clarkson University Women's Lacrosse Golden Kn...
# ...                   ...                                                ...
# 5191          3230716.txt  Arizona Olympian Gymnastics Offers preschool, ...
# 13418         3273956.txt  It's Showtime Includes articles, news, picture...
# 5390          3231189.txt  Manitoba Gymnastics Association Provides infor...
# 860           3195572.txt  Saginaw Valley Men's Basketball Cardinals. Sch...
# 7270          3243863.txt  VARAC Vintage Automobile Racing Association of...
#
#              class                                      text_features
# 12745       Winter  [-0.2771798, -0.014207737, -0.0017138981, 0.13...
# 2450       Cycling  [0.008829312, -0.13896446, -4.4838565e-05, 0.0...
# 8261       Running  [-0.16413541, 0.25168875, 0.0012479315, 0.1028...
# 7058   Motorsports  [-0.09343644, -0.060069505, -0.0010917239, 0.1...
# 6141      Lacrosse  [-0.017799444, 0.16569644, -0.0055210395, 0.09...
# ...            ...                                                ...
# 5191    Gymnastics  [-0.23215884, -0.104245715, -0.0072811744, 0.1...
# 13418    Wrestling  [-0.12814336, 0.10038537, -0.0051835612, 0.017...
# 5390    Gymnastics  [-0.20877513, 0.14891854, -0.0034147538, 0.179...
# 860     Basketball  [-0.20442742, 0.15170267, -0.0019212218, 0.092...
# 7270   Motorsports  [-0.14502175, 0.14868861, -0.0030329456, 0.194...
#
# [10800 rows x 4 columns]

# %%
df_test
# Out:
#                    file_name  \
# 1483             3200794.txt
# 12892     Sports_3273255.txt
# 1175             3201211.txt
# 6554        Arts_3237795.txt
# 11039  and_Field_3265475.txt
# ...                      ...
# 10661            3264759.txt
# 13070            3273838.txt
# 6243             3235362.txt
# 3107             3216945.txt
# 12854     Sports_3272071.txt
#
#                                                     text      class  \
# 1483   Bomaderry Bowling Club Devoted to enjoyment an...    Bowling
# 12892  SnowboardSeattle.com Articles on backcountry s...     Winter
# 1175   W.D. Tournaments Woody Demma and several Chica...    Bowling
# 6554   Northern Karate Schools Blending the tradition...    Martial
# 11039  North Carolina Central University - Track and ...      Track
# ...                                                  ...        ...
# 10661  The Official Lleyton Hewitt Web Page Official ...     Tennis
# 13070  WWE Corpbiz Official site of the parent compan...  Wrestling
# 6243   Curry College Men's Lacrosse Colonels. Provide...   Lacrosse
# 3107   Tyshler Fencing School Location, cost, coach b...    Fencing
# 12854  This is Your Brain in the Backcountry Some bas...     Winter
#
#                                            text_features
# 1483   [-0.086449936, 0.22722998, -0.00022814874, 0.0...
# 12892  [-0.148869, 0.2836484, -0.0017952527, 0.170473...
# 1175   [-0.12716374, -0.009309612, -0.0010912316, 0.1...
# 6554   [-0.014099523, 0.25415033, 0.0003747005, 0.142...
# 11039  [-0.1598681, 0.080623664, 0.0032643853, 0.0919...
# ...                                                  ...
# 10661  [0.03826355, 0.22084396, -0.0010818656, 0.1811...
# 13070  [0.0006317993, 0.05516456, -0.0026034438, 0.08...
# 6243   [-0.07501134, 0.26612765, -0.00028457347, 0.07...
# 3107   [-0.007180855, 0.19359075, 0.0005010359, 0.164...
# 12854  [-0.055940725, 0.11314705, -0.0008704635, 0.10...
#
# [2700 rows x 4 columns]

# %% [markdown]
# ### Instanciando o K-NN

# %%
knn = KNeighborsClassifier(n_neighbors=3, metric='cosine')
knn.fit(df_train['text_features'].to_list(), df_train['class'].to_list())
# Out:
# KNeighborsClassifier(metric='cosine', n_neighbors=3)

# %%
preds = knn.predict(df_test['text_features'].to_list())
df_test['preds'] = preds
df_test
# Out:
#                    file_name  \
# 1483             3200794.txt
# 12892     Sports_3273255.txt
# 1175             3201211.txt
# 6554        Arts_3237795.txt
# 11039  and_Field_3265475.txt
# ...                      ...
# 10661            3264759.txt
# 13070            3273838.txt
# 6243             3235362.txt
# 3107             3216945.txt
# 12854     Sports_3272071.txt
#
#                                                     text      class  \
# 1483   Bomaderry Bowling Club Devoted to enjoyment an...    Bowling
# 12892  SnowboardSeattle.com Articles on backcountry s...     Winter
# 1175   W.D. Tournaments Woody Demma and several Chica...    Bowling
# 6554   Northern Karate Schools Blending the tradition...    Martial
# 11039  North Carolina Central University - Track and ...      Track
# ...                                                  ...        ...
# 10661  The Official Lleyton Hewitt Web Page Official ...     Tennis
# 13070  WWE Corpbiz Official site of the parent compan...  Wrestling
# 6243   Curry College Men's Lacrosse Colonels. Provide...   Lacrosse
# 3107   Tyshler Fencing School Location, cost, coach b...    Fencing
# 12854  This is Your Brain in the Backcountry Some bas...     Winter
#
#                                            text_features       preds
# 1483   [-0.086449936, 0.22722998, -0.00022814874, 0.0...     Bowling
# 12892  [-0.148869, 0.2836484, -0.0017952527, 0.170473...      Winter
# 1175   [-0.12716374, -0.009309612, -0.0010912316, 0.1...  Gymnastics
# 6554   [-0.014099523, 0.25415033, 0.0003747005, 0.142...     Martial
# 11039  [-0.1598681, 0.080623664, 0.0032643853, 0.0919...       Track
# ...                                                  ...         ...
# 10661  [0.03826355, 0.22084396, -0.0010818656, 0.1811...      Hockey
# 13070  [0.0006317993, 0.05516456, -0.0026034438, 0.08...   Wrestling
# 6243   [-0.07501134, 0.26612765, -0.00028457347, 0.07...    Lacrosse
# 3107   [-0.007180855, 0.19359075, 0.0005010359, 0.164...     Fencing
# 12854  [-0.055940725, 0.11314705, -0.0008704635, 0.10...      Winter
#
# [2700 rows x 5 columns]

# %%
print(classification_report(df_test['class'].to_list(), df_test['preds'].to_list()))
# Out:
#               precision    recall  f1-score   support
#
#     Baseball       0.50      0.68      0.57       114
#   Basketball       0.66      0.89      0.76       102
#      Bowling       0.92      0.89      0.90       101
#      Cricket       0.77      0.94      0.85        90
#      Cycling       0.88      0.92      0.90       107
#   Equestrian       0.90      0.87      0.89        95
#      Fencing       0.76      0.94      0.84       111
#       Flying       0.77      0.59      0.67        97
#     Football       0.59      0.41      0.49       107
#         Golf       0.87      0.96      0.91        94
#   Gymnastics       0.83      0.93      0.88        95
#       Hockey       0.83      0.57      0.68       101
#     Lacrosse       0.70      0.89      0.78       100
#      Martial       0.93      0.93      0.93        88
#  Motorsports       0.84      0.79      0.82       101
#    Paintball       0.88      0.90      0.89        84
#      Running       0.82      0.83      0.83       108
#      Skating       0.88      0.85      0.87       107
#       Soccer       0.77      0.73      0.75       102
#     Softball       0.72      0.72      0.72       114
#     Strength       0.90      0.92      0.91        86
#       Tennis       0.90      0.84      0.87       106
#        Track       0.85      0.69      0.76        98
#   Volleyball       0.87      0.71      0.78        82
#        Water       0.96      0.85      0.90       104
#       Winter       0.94      0.98      0.96        90
#    Wrestling       0.91      0.74      0.82       116
#
#     accuracy                           0.81      2700
#    macro avg       0.82      0.81      0.81      2700
# weighted avg       0.82      0.81      0.81      2700

# %% [markdown]
# # Usando o classificador para novos textos

# %%
knn_all = KNeighborsClassifier(n_neighbors=3, metric='cosine')
knn_all.fit(df['text_features'].to_list(), df['class'].to_list())
# Out:
# KNeighborsClassifier(metric='cosine', n_neighbors=3)

# %%
texto_entrada = 'A primeira corrida vencida por Senna na Fórmula 1 foi em 21 de abril de 1985'
features = text_feature_extractor.encode([texto_entrada])
knn_all.predict(features)
# Out:
# array(['Motorsports'], dtype='<U11')

# %%
texto_entrada = 'O Flamengo venceu o campeonato brasileiro'
features = text_feature_extractor.encode([texto_entrada])
knn_all.predict(features)
# Out:
# array(['Soccer'], dtype='<U11')

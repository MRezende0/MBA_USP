# %% [markdown]
# # AULA 22 - SVM - Prática

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.inspection import DecisionBoundaryDisplay

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import make_blobs, make_gaussian_quantiles
from sklearn.metrics import classification_report

# %% [markdown]
# # Função de Apoio para treinar um SVM e visualizar a função de decisão, margem de separação e vetores de suporte!

# %%
# Adaptado de
# https://scikit-learn.org/stable/auto_examples/svm/plot_svm_kernels.html#sphx-glr-auto-examples-svm-plot-svm-kernels-py
def svm_fit_plot(
    clf, X, y, ax=None, long_title=True, support_vectors=True
):
    # treina o modelo
    clf.fit(X, y)

    # plot
    _, ax = plt.subplots(figsize=(6, 5))

    common_params = {"estimator": clf, "X": X, "ax": ax}
    DecisionBoundaryDisplay.from_estimator(
        **common_params,
        response_method="predict",
        plot_method="pcolormesh",
        alpha=0.3,
    )
    DecisionBoundaryDisplay.from_estimator(
        **common_params,
        response_method="decision_function",
        plot_method="contour",
        levels=[-1, 0, 1],
        colors=["k", "k", "k"],
        linestyles=["--", "-", "--"],
    )

    if support_vectors:
        # Fazer um circulo nas instancias que representam vetores de suporte
        ax.scatter(
            clf.support_vectors_[:, 0],
            clf.support_vectors_[:, 1],
            s=150,
            facecolors="none",
            edgecolors="k",
        )

    # plotar e colorir conforme classe.
    ax.scatter(X[:, 0], X[:, 1], c=y, s=30, edgecolors="k")

    if ax is None:
        plt.show()

# %% [markdown]
# # Construindo nosso conjunto de dados

# %%
from sklearn.datasets import make_blobs

data, labels = make_blobs(n_features=2,centers=2,cluster_std=1,random_state=42)
sns.scatterplot(data=pd.DataFrame(data), x=0, y=1,hue=labels)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %% [markdown]
# # SVM com Kernel Linear

# %%
X = data
y = labels
clf = svm.SVC(kernel="linear",C=1)
svm_fit_plot(clf,X,y)

# %% [markdown]
# # Vamos dificultar um pouco mais...

# %%
# Quanto maior o cluster_std, maior será a sobreposição!
data, labels = make_blobs(n_features=2,centers=2,cluster_std=3,random_state=42)
sns.scatterplot(data=pd.DataFrame(data), x=0, y=1,hue=labels)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %% [markdown]
# # SVM com Kernel Linear
#
# Observe que é difícil definir uma boa margem de separação para problemas mais complexos!

# %%
X = data
y = labels
clf = svm.SVC(kernel="linear",C=1)
svm_fit_plot(clf,X,y)

# %% [markdown]
# # SVM com Kernel polinomial

# %%
X = data
y = labels
clf = svm.SVC(kernel="poly",C=1)
svm_fit_plot(clf,X,y)

# %% [markdown]
# # SVM com Kernel RBF

# %%
X = data
y = labels
clf = svm.SVC(kernel="rbf",C=1)
svm_fit_plot(clf,X,y)

# %% [markdown]
# # Vamos experimental com um exemplo típico: xor é não linearmente separável.

# %%
data = np.random.randn(300, 2)
labels = np.logical_xor(data[:, 0] > 0, data[:, 1] > 0)
sns.scatterplot(data=pd.DataFrame(data), x=0, y=1,hue=labels)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %% [markdown]
# # SVM com Kernel Linear

# %%
X = data
y = labels
clf = svm.SVC(kernel="linear",C=1)
svm_fit_plot(clf,X,y)

# %% [markdown]
# # SVM com Kernel RBF

# %%
X = data
y = labels
clf = svm.SVC(kernel="rbf",C=1)
svm_fit_plot(clf,X,y)

# %% [markdown]
# # Experimento Final
#
# GridSearch para estimar um bom modelo SVM

# %%
data, labels = make_gaussian_quantiles(n_features=2, n_samples=500,  n_classes=2, random_state=42)
sns.scatterplot(data=pd.DataFrame(data), x=0, y=1,hue=labels)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, random_state=0)

parameters = {
    'kernel':('linear','rbf','poly','sigmoid'),
    'C':[0.1, 1, 10, 100, 1000]
    }

skfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

grid_search = GridSearchCV(svm.SVC(), parameters, cv=skfold, scoring='accuracy')
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'kernel': ('linear', 'rbf', 'poly', 'sigmoid')},
#              scoring='accuracy')

# %% [markdown]
# Verificando os resultados experimentais

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.002612      0.002446         0.004933        0.002380      0.1
# 1        0.003597      0.002502         0.003525        0.003283      0.1
# 2        0.002427      0.002434         0.000510        0.001021      0.1
# 3        0.003344      0.001697         0.001544        0.001289      0.1
# 4        0.002999      0.002900         0.000600        0.000735      1.0
# 5        0.003503      0.003068         0.001193        0.002137      1.0
# 6        0.003479      0.002050         0.001091        0.001358      1.0
# 7        0.004722      0.001651         0.000881        0.001080      1.0
# 8        0.005882      0.003976         0.000910        0.001135     10.0
# 9        0.002793      0.002200         0.000917        0.000906     10.0
# 10       0.012769      0.002749         0.001366        0.001574     10.0
# 11       0.004716      0.001915         0.000134        0.000267     10.0
# 12       0.020355      0.002432         0.003371        0.002799    100.0
# 13       0.001554      0.001787         0.001274        0.002285    100.0
# 14       0.066022      0.004973         0.002468        0.002256    100.0
# 15       0.002741      0.001701         0.001859        0.001843    100.0
# 16       0.164783      0.045782         0.000945        0.000425   1000.0
# 17       0.002862      0.002818         0.001188        0.001165   1000.0
# 18       1.032687      0.620189         0.001939        0.002045   1000.0
# 19       0.004402      0.003450         0.001615        0.002477   1000.0
#
#    param_kernel                            params  split0_test_score  \
# 0        linear    {'C': 0.1, 'kernel': 'linear'}           0.671429
# 1           rbf       {'C': 0.1, 'kernel': 'rbf'}           0.985714
# 2          poly      {'C': 0.1, 'kernel': 'poly'}           0.528571
# 3       sigmoid   {'C': 0.1, 'kernel': 'sigmoid'}           0.657143
# 4        linear      {'C': 1, 'kernel': 'linear'}           0.671429
# 5           rbf         {'C': 1, 'kernel': 'rbf'}           0.985714
# 6          poly        {'C': 1, 'kernel': 'poly'}           0.528571
# 7       sigmoid     {'C': 1, 'kernel': 'sigmoid'}           0.700000
# 8        linear     {'C': 10, 'kernel': 'linear'}           0.671429
# 9           rbf        {'C': 10, 'kernel': 'rbf'}           0.985714
# 10         poly       {'C': 10, 'kernel': 'poly'}           0.528571
# 11      sigmoid    {'C': 10, 'kernel': 'sigmoid'}           0.528571
# 12       linear    {'C': 100, 'kernel': 'linear'}           0.671429
# 13          rbf       {'C': 100, 'kernel': 'rbf'}           0.985714
# 14         poly      {'C': 100, 'kernel': 'poly'}           0.528571
# 15      sigmoid   {'C': 100, 'kernel': 'sigmoid'}           0.557143
# 16       linear   {'C': 1000, 'kernel': 'linear'}           0.671429
# 17          rbf      {'C': 1000, 'kernel': 'rbf'}           0.971429
# 18         poly     {'C': 1000, 'kernel': 'poly'}           0.528571
# 19      sigmoid  {'C': 1000, 'kernel': 'sigmoid'}           0.571429
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.528571           0.571429           0.628571
# 1            0.971429           0.928571           0.957143
# 2            0.528571           0.614286           0.528571
# 3            0.571429           0.500000           0.614286
# 4            0.528571           0.557143           0.614286
# 5            0.985714           0.957143           0.914286
# 6            0.528571           0.614286           0.514286
# 7            0.642857           0.500000           0.628571
# 8            0.528571           0.557143           0.642857
# 9            0.971429           0.971429           0.957143
# 10           0.528571           0.614286           0.514286
# 11           0.514286           0.500000           0.528571
# 12           0.542857           0.557143           0.642857
# 13           0.985714           0.985714           0.985714
# 14           0.528571           0.614286           0.514286
# 15           0.600000           0.500000           0.528571
# 16           0.542857           0.557143           0.642857
# 17           0.985714           1.000000           0.957143
# 18           0.528571           0.614286           0.514286
# 19           0.600000           0.500000           0.528571
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.657143         0.611429        0.053757               10
# 1            0.971429         0.962857        0.019378                4
# 2            0.514286         0.542857        0.036140               13
# 3            0.571429         0.582857        0.052216               12
# 4            0.685714         0.611429        0.061545               10
# 5            0.971429         0.962857        0.026496                5
# 6            0.514286         0.540000        0.037688               14
# 7            0.628571         0.620000        0.065528                6
# 8            0.685714         0.617143        0.062857                9
# 9            0.985714         0.974286        0.010690                3
# 10           0.514286         0.540000        0.037688               14
# 11           0.457143         0.505714        0.026496               20
# 12           0.685714         0.620000        0.058971                7
# 13           1.000000         0.988571        0.005714                1
# 14           0.514286         0.540000        0.037688               14
# 15           0.457143         0.528571        0.048655               19
# 16           0.685714         0.620000        0.058971                7
# 17           1.000000         0.982857        0.016660                2
# 18           0.514286         0.540000        0.037688               14
# 19           0.457143         0.531429        0.050629               18

# %% [markdown]
# Identificando os melhores parâmetros e o desempenho associado

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'C': 100, 'kernel': 'rbf'}
# 0.9885714285714287

# %% [markdown]
# Utilizando o modelo com o melhor parâmetro para predição final no conjunto de teste

# %%
clf = grid_search.best_estimator_
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        75
#            1       0.99      0.97      0.98        75
#
#     accuracy                           0.98       150
#    macro avg       0.98      0.98      0.98       150
# weighted avg       0.98      0.98      0.98       150

# %% [markdown]
# Vamos comparar com uma DecisionTreeClassifier

# %%
parameters = {
    'criterion':('entropy','gini'),
    'max_depth':[3, 5, 10, None]
    }

grid_search = GridSearchCV(DecisionTreeClassifier(random_state=0), parameters, cv=skfold, scoring='accuracy')
grid_search.fit(X_train, y_train)

print('Melhores parametros e scores:')
print(grid_search.best_params_)
print(grid_search.best_score_)

print('Usando nosso melhor classificador no teste:')
clf = grid_search.best_estimator_
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# Melhores parametros e scores:
# {'criterion': 'entropy', 'max_depth': 10}
# 0.9457142857142857
# Usando nosso melhor classificador no teste:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94        75
#            1       0.99      0.89      0.94        75
#
#     accuracy                           0.94       150
#    macro avg       0.94      0.94      0.94       150
# weighted avg       0.94      0.94      0.94       150

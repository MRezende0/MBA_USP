# %% [markdown]
# # SCC-ICMC-USP
# ## CURSO 2 - CD_AM_DM
#
# ##MBA em IA e BIGDATA
# ### Profa. Roseli A. F. Romero
# ### Prof. Ricardo M. Marcacini
# ### **AVALIAÇÃO FINAL**

# %% [markdown]
# ---
# ### Questão 1.
#
# Para transformar os valores de um atributo numérico de um conjunto de dados para que fiquem com média zero e variância igual a 1, usamos que função do sklearn:
#
# a) StandardScaler </br>
# b) MinMaxScaler </br>
# c) One Hot Encoder </br>
# d) Label Encoder </br>

# %% [markdown]
# ---
# ### Questão 2.
#
# Para transformar os valores de um atributo categórico ou nominal, de conjunto de dados, em valores numéricos (e não lista de valores numéricos), usamos que função do sklearn:
#
# a) StandardScaler </br>
# b) MinMaxScaler  </br>
# c) One Hot Encoder  </br>
# d) Label Encoder  </br>

# %% [markdown]
# ---
# ### Questão 3.
#
# Imagine um conjunto de dados com informações de clientes de uma loja online. Durante a análise inicial, você observa a presença de valores ausentes, erros de digitação em nomes de cidades, duplicatas e outliers em variáveis numéricas como "idade" e "renda mensal". Com base nessas informações,  suponha que a variável "idade" contenha valores como -5, 0, 1200. Considerando que existem várias alternativas para tratar esses outliers, qual das alternativas abaixo não é a mais indicada. trataria?
#
# a) substituir pela média dos valores presentes no atributo idade. </br>
#
# b) eliminar o atributo idade da base de dados. </br>
#
# c) substituir pela moda dos valores presentes no atributo idade. </br>
#
# d) eliminar os objetos (ou linhas ) da base de dados, que possuem esses valores. </br>

# %% [markdown]
# ---
# ### Questão 4.
#
# Considere o dataset `Abalone` presente no arquivo `abalone.csv`. O objetivo desse dataset é determinar a idade de um molusco a partir de 8 atributos. Os quatro momentos estatísticos para os atributo `Diameter` e `Whole weight` são, respectivamente:
#
# a) Média: 0.41 e 0.83; Variância: 0.01 e 0.24; Obliquidade: -0.61 e 0.53; Achatamento: -0.05 e -0.02<br>
# b) Média: 0.45 e 0.73; Variância: 0.01 e 0.24; Obliquidade: -0.61 e 0.53; Achatamento: -0.05 e -0.02<br>
# c) Média: 0.41 e 0.83; Variância: 0.05 e 0.20; Obliquidade: -0.61 e 0.53; Achatamento: -0.05 e -0.02<br>
# d) Média: 0.41 e 0.83; Variância: 0.01 e 0.24; Obliquidade: -0.31 e -0.53; Achatamento: -0.05 e -0.02<br>
# e) Média: 0.41 e 0.83; Variância: 0.01 e 0.24; Obliquidade: -0.61 e 0.53; Achatamento: -0.35 e -0.12

# %% [markdown]
# ---
#
# ### Questão 5.
#
# Considere o dataset `Adult Data Set` disponível no arquivo `adult.csv`. A ideia desse dataset é classificar se um determinado indivíduo recebe mais ou menos de 50.000 dólares/ano (atributo `Income`). Dados faltantes são representados pelo caractere `?`. Fazendo uma breve exploração dos dados, podemos afirmar:
#
#
# a) possui 6 atributos numéricos; 9 atributos categóricos; 1502, 1843 e 583 dados faltantes para os atributos workclass, occupation e native-country, respectivamente<br>
# b) possui 9 atributos numéricos; 6 atributos categóricos; 583, 1040 e 1836 dados faltantes para os atributos workclass, occupation e native-country, respectivamente<br>
# c) possui 6 atributos numéricos; 9 atributos categóricos; 1836, 1843 e 583 dados faltantes para os atributos workclass, occupation e native-country, respectivamente<br>
# d) possui 9 atributos numéricos; 6 atributos categóricos; 1366, 683 e 583 dados faltantes para os atributos workclass, occupation e native-country, respectivamente<br>

# %% [markdown]
# ### Questão 6.
#
# Qual das alternativas abaixo expressa corretamente uma suposição central do classificador Naive Bayes?
#
# a) As classes são balanceadas e linearmente separáveis.<br>
# b) Todas as features são correlacionadas entre si.<br>
# c) A distribuição das features segue uma curva normal sempre.<br>
# d) A probabilidade conjunta das classes é constante.<br>
# e) As features são independentes entre si, dado a classe.<br>

# %% [markdown]
# ### Questão 7.
#
# Em uma árvore de decisão, qual métrica é mais comumente usada para decidir a melhor divisão de um nó?
#
# a) Gini ou Entropia.<br>
# b) Regressão linear.<br>
# c) Valor médio da variável-alvo.<br>
# d) Correlação de Pearson.<br>
# e) Número de amostras com ruído.<br>

# %% [markdown]
# ### Questão 8.
# O que caracteriza uma Random Forest em relação a uma árvore de decisão única?
#
# a) Usa apenas uma árvore, mas com profundidade ilimitada.<br>
# b) Realiza clustering em vez de classificação.<br>
# c) Constrói múltiplas árvores com diferentes subconjuntos de dados e features.<br>
# d) Treina uma rede neural antes de gerar as árvores.<br>
# e) Utiliza regressão linear nas folhas da árvore.<br>

# %% [markdown]
#  ### Questão 9.
#  Qual é a principal característica de uma SVM linear?
#
# a) Classifica instâncias usando uma média das classes.<br>
# b) Encontra um hiperplano que maximiza a margem entre as classes.<br>
# c) Cria um modelo baseado na frequência das palavras.<br>
# d) Constrói várias árvores para melhorar a acurácia.<br>
# e) Aplica k-means para separar os dados.<br>

# %% [markdown]
# ### Questão 10.
# Sobre o classificador KNN, escolha a alternativa correta em relação à a como o algoritmo escolher a classe
#
# a) Uma árvore de decisão gerada a partir dos dados.<br>
# b) Um modelo estatístico ajustado previamente.<br>
# c) A média dos valores previstos em todas as classes.<br>
# d) Considera as classes dos k vizinhos mais próximos no espaço de atributos.<br>
# e) O desvio padrão dos dados de entrada.<br>
